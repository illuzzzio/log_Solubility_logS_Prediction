# %%
import pandas as pd 
df = pd.read_csv("solubility_data.csv")
df #by calling the variable we can get the data
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %%
#Data Seperation#  # This code helsp su to visualise specifically the logS column 


y = df["logS"]
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
# now we will get the data without logS column#


x = df.drop("logS", axis=1)  #axis = 1 , means drop the column (means vertical section), axis = 0 means drop the horizontal row , so here we need to dro pthe column of logS
x
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %%
# DATA SPLITTING USIGN SCIKIT LEARN #


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
#X_train: Training set for features.
# X_test: Testing set for features.
# y_train: Training set for the target variable.
# y_test: Testing set for the target variable.
# test_size: Specifies the proportion of the dataset to be allocated to the test set (e.g., 0.2 for 20%).
# random_state: An integer used to initialize the random number generator, ensuring reproducible splits across multiple runs.

X_train
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 643   3.61260  296.410                0.0            0.272727
# 722   6.48760  226.448               13.0            0.000000
# 570   3.15380  284.746                1.0            0.600000
# 66    0.77880   74.123                2.0            0.000000
# 1002  1.82140  102.177                3.0            0.000000
# ...       ...      ...                ...                 ...
# 1044  2.82960  253.305                1.0            0.631579
# 1095  2.10750  218.322                3.0            0.000000
# 1130  4.14820  335.282                7.0            0.260870
# 860   4.25720  275.179                4.0            0.352941
# 1126  6.25676  368.369                6.0            0.692308
#
# [915 rows x 4 columns]

# %%
X_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 218   1.55740  102.177                3.0            0.000000
# 809   5.20590  345.653                4.0            0.571429
# 501   4.18090  339.218                4.0            0.545455
# 649   2.05760  286.349                4.0            0.315789
# 323   0.72822  146.153                0.0            0.909091
# ...       ...      ...                ...                 ...
# 361  -0.50840   59.068                0.0            0.000000
# 292   1.94750  116.204                3.0            0.000000
# 1119  2.16090  257.437                3.0            0.000000
# 557   3.36680  138.254                0.0            0.000000
# 448   1.40120  108.966                0.0            0.000000
#
# [229 rows x 4 columns]

# %%
#MODEL-BUILDING(specifically training the model) using LINEAR_REGRESSION_ALGO#

from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X_train,y_train)
LinearRegression()   # Till here the model is ready
# Out:
# LinearRegression()

# %%
#Applyign the model to make a prediction#

y_LR_train_predict = LR.predict(X_train)
y_LR_test_predict  = LR.predict(X_test)

y_LR_train_predict  # prediction made on 80 percent trained data
# Out:
# array([ -4.47026156,  -5.88839323,  -4.22029229,  -0.79352323,
#         -1.73062942,  -1.26187649,  -1.43969557,  -2.36087206,
#         -2.77481055,  -2.23755209,  -4.15424648,  -8.49226359,
#         -4.26355722,  -1.5773174 ,  -2.61749814,  -0.72935686,
#         -3.18513222,  -3.71048234,  -1.57995763,  -5.11539503,
#         -1.90340063,  -4.18841892,  -4.85523085,  -2.13317387,
#         -3.34701685,  -3.45842365,  -3.73715663,  -3.61882675,
#         -3.02530867,  -2.82178231,  -1.54861269,  -2.73630968,
#         -1.79353838,  -6.49056433,  -2.19068424,  -4.10802907,
#         -2.7303035 ,  -2.28598248,  -2.60739155,  -3.64519507,
#         -2.65218678,  -4.35285798,   1.91721982,  -3.70871993,
#         -3.50138017,  -2.71898539,  -4.77720737,  -3.38184768,
#         -1.71815824,  -2.79713356,  -5.26774517,  -2.96884167,
#         -2.27709013,  -2.76017539,  -2.12748391,  -2.3140745 ,
#         -7.74681081,  -3.21253144,  -1.76376134,  -4.17337487,
# ...

# %%
y_LR_test_predict # these are the predictions made on test data which was 20 percent of the original data
# Out:
# array([-1.53917269, -6.08287944, -5.28375883, -3.27746087, -1.70320929,
#        -5.63167711, -1.43239582, -2.74544339, -3.43274443, -3.79048137,
#        -1.26884289, -1.54861269, -3.72258406, -3.25962057, -3.76344744,
#        -2.13317387, -2.00365994, -4.80828381, -1.43582956, -2.81358533,
#        -2.37870232, -1.45080608, -3.71048234, -3.06158669, -1.12854214,
#        -1.11007232, -2.45566761, -5.0338893 , -3.29087978, -4.21832264,
#        -2.45834377, -3.09200621, -3.89726792, -1.85208473, -2.17761301,
#        -6.01542152, -1.06493784, -2.35071265, -1.72034021, -1.45695216,
#        -1.85208473, -6.66998091, -1.23899725, -1.46015868, -1.65115215,
#        -3.79048137, -4.73551134, -1.09859266, -0.69404611, -1.91048017,
#        -3.16121056, -2.34753749, -2.01980335, -2.51436431, -7.04012802,
#        -5.27488937, -4.18979204, -2.9647599 , -1.7364388 , -1.64388527,
#        -4.60884756, -4.84900677, -0.18955927, -1.73839902, -1.63779456,
# ...

# %%
#COMPARING AND EVALUATING MODEL-PERFORMANCE#


y_train # y_train was the actual values for the variable y as a fucntion of x i.e logS Values of that 80 percent of data to be trained earlier
# Out:
# 643    -4.300
# 722    -8.400
# 570    -3.754
# 66      0.000
# 1002   -1.340
#         ...
# 1044   -3.324
# 1095   -1.620
# 1130   -5.680
# 860    -4.770
# 1126   -6.010
# Name: logS, Length: 915, dtype: float64

# %%
y_LR_train_predict # it is the predicted values of y on the 80 percent of data trained earlier

# %%
#FINAL MODEL EVALUATION#

from sklearn.metrics import mean_squared_error, r2_score
#mean_squared_error (MSE):

 # Purpose: This function calculates the Mean Squared Error, which is a common metric to quantify the average squared difference between the actual (true) values and the predicted values from a regression model.

 #r2_score (R-squared or Coefficient of Determination):

#Purpose: This function calculates the R-squared score, which measures the proportion of the variance in the dependent variable that is predictable from the independent variable(s). In simpler terms, it indicates how well the regression model explains the variability in the target variable


#First lets do it for training models:
LR_train_mse = mean_squared_error(y_train, y_LR_train_predict) 
LR_train_r2 = r2_score(y_train, y_LR_train_predict)
# comparision of both for evaluation of the model 

#Now lets do this for testing models:
LR_test_mse = mean_squared_error(y_test,y_LR_test_predict)
LR_test_r2 = r2_score(y_test,y_LR_test_predict)

print("LR MSE (TRAIN): ",LR_train_mse)
print("LR r2 (TRAIN): ",LR_train_r2)
print("LR MSE (TEST): ",LR_test_mse)
print("LR r2 (TEST): ",LR_test_r2)

# Above i am printing our results 


LR_results = pd.DataFrame(["Linear Regression Model", LR_train_mse, LR_train_r2, LR_test_mse, LR_test_r2]).transpose()
LR_results.columns= ["Method","Training MSE","TrainingR2","Test MSE","Test R2"] # This we are doing to maek data more tidy 
LR_results
# Out:
# LR MSE (TRAIN):  1.0139894491573003
# LR r2 (TRAIN):  0.7695127746587307
# LR MSE (TEST):  0.9990844407075304
# LR r2 (TEST):  0.7705650058569232
#                     Method Training MSE TrainingR2  Test MSE   Test R2
# 0  Linear Regression Model     1.013989   0.769513  0.999084  0.770565

# %%
##Training model using Random Forest Algo#

from sklearn.ensemble import RandomForestRegressor

RF = RandomForestRegressor(max_depth=2, random_state=100)

RF.fit(X_train,y_train)
RF
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %%
#Now Applying Random Forest Model to Make Predictions , just like Before #

y_RF_train_predict = RF.predict(X_train)
y_RF_test_predict =  RF.predict(X_test)

# %%
#MODEL EVALUATION using RANDOM-FOREST#
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# Training metrics
RF_train_mse = mean_squared_error(y_train, y_RF_train_predict) 
RF_train_r2 = r2_score(y_train, y_RF_train_predict)

# Testing metrics
RF_test_mse = mean_squared_error(y_test, y_RF_test_predict)
RF_test_r2 = r2_score(y_test, y_RF_test_predict)

# Collect results in DataFrame
RF_results = pd.DataFrame(["Random Forest Model", RF_train_mse, RF_train_r2, RF_test_mse, RF_test_r2]).transpose()
RF_results.columns= ["Method","Training MSE","TrainingR2","Test MSE","Test R2"] # This we are doing to maek data more tidy 
RF_results
# Out:
#                 Method Training MSE TrainingR2 Test MSE   Test R2
# 0  Random Forest Model     1.057186   0.759694  1.05209  0.758393

# %%
#FINAL MODEL COMPARISION WITH COMBINING THE TABLES
FINAL_RESULT = pd.concat([LR_results,RF_results], axis=0)

FINAL_RESULT
FINAL_RESULT.reset_index(drop=True) # to get 0 and 1 index
# Out:
#                     Method Training MSE TrainingR2  Test MSE   Test R2
# 0  Linear Regression Model     1.013989   0.769513  0.999084  0.770565
# 1      Random Forest Model     1.057186   0.759694   1.05209  0.758393

# %%
#RESULT DATA VISUALIZATION for linear regression model#
import matplotlib.pyplot as plt
import numpy as np

# Scatter plot of actual vs predicted
plt.scatter(x=y_train, y=y_LR_train_predict, alpha=0.3)

# Fit and plot a regression line
z = np.polyfit(y_train, y_LR_train_predict, 1)
p = np.poly1d(z)

# Sort y_train to make line plot smooth
y_train_sorted = np.sort(y_train)
plt.plot(y_train_sorted, p(y_train_sorted), color='red', linewidth=2)

# Labels
plt.xlabel("logS_Original_Values")
plt.ylabel("logS_Predicted")
plt.title("Linear Regression - Training Predictions")

plt.grid(True)
plt.show()

# %%
#Resultt data visualization for Random Forest 

import matplotlib.pyplot as plt
import numpy as np

# Scatter plot of actual vs predicted (Random Forest)
plt.scatter(x=y_train, y=y_RF_train_predict, alpha=0.3)

# Fit and plot a regression line
z = np.polyfit(y_train, y_RF_train_predict, 1)
p = np.poly1d(z)

# Sort y_train to make line plot smooth
y_train_sorted = np.sort(y_train)
plt.plot(y_train_sorted, p(y_train_sorted), color='green', linewidth=2)

# Labels
plt.xlabel("logS_Original_Values")
plt.ylabel("logS_Predicted")
plt.title("Random Forest - Training Predictions")

plt.grid(True)
plt.show()
